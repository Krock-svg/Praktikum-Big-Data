# %%
# Soal 1.** Buatlah sebuah DataFrame baru bernama `df_nilai` yang berisi data nilai 5 mahasiswa (kolom: `nama`, `uts`, `uas`). 
# Tambahkan kolom baru `nilai_akhir` yang dihitung dari `(uts * 0.4) + (uas * 0.6)`."
import sys
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

df_nilai = {
    'nama' : ["Sujatmiko Arafuru", "Wilson Lo Siento", "Peter Zaqaf", "Bahaha Von Hormus", "Patar Zaqaf"],
    'uts' : [98, 87, 78, 56, 84],
    'uas' : [89, 86, 76, 45, 86],
}


df = pd.DataFrame(df_nilai)

# df.describe()

df['nilai_akhir'] = (df['uts'] * 0.4) + (df['uas'] * 0.6) 

# Soal 2.** Dari DataFrame `df_nilai` yang telah dibuat, tampilkan hanya mahasiswa dengan `nilai_akhir` di atas 80."

df_nilai = df[df['nilai_akhir'] > 80]

df_nilai
# Out:
#                 nama  uts  uas  nilai_akhir
# 0  Sujatmiko Arafuru   98   89         92.6
# 1   Wilson Lo Siento   87   86         86.4
# 4        Patar Zaqaf   84   86         85.2

# %%
import pandas as pd

df_nilai = {
    'nama' : ["Sujatmiko Arafuru", "Wilson Lo Siento", "Peter Zaqaf", "Bahaha Von Hormus", "Patar Zaqaf"],
    'uts' : [98, 87, 78, 56, 84],
    'uas' : [89, 86, 76, 45, 86],
}


df = pd.DataFrame(df_nilai)

# df.describe()

#df['nilai_akhir'] = (df['uts'] * 0.4) + (df['uas'] * 0.6) 

# Soal 2.** Dari DataFrame `df_nilai` yang telah dibuat, tampilkan hanya mahasiswa dengan `nilai_akhir` di atas 80."

#df_nilai = df[df['nilai_akhir'] > 80]

# df_nilai

# data_filter = df[(df['uts'] > 70) & (df['uas'] <80)]
# data_filter

total_nilai = df.groupby("nama")["nilai_akhir"].sum().sort_values(ascending=False)"
print("Total nilai akhir: ")
total_nilai
# Out:
#   Cell In[49], line 25
#     total_nilai = df.groupby("nama")["nilai_akhir"].sum().sort_values(ascending=False)"
#                                                                                       ^
# SyntaxError: unterminated string literal (detected at line 25)
